# %%
inputstring = input("Please enter your hexadecimal number ")

decnum = 0
for power, digit in enumerate(reversed(inputstring)):
  decnum += int(digit, 16)*(16**power)

print(f"Your decimal number is {decnum}")
# Out:
# Please enter your hexadecimal number ff
# Your decimal number is 255

# %%
chr?
